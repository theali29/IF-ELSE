# %% [markdown]
# # Quiz 1

# %%
# Q1
#Answer
#1)first import numpy library as np
#2)after reading data in a variable
#3)data is read in a df variable
#4)df.replace("-",np.nan,inplace=True) replacing '-' with nan in df
#5)df.isnull() replacing false values where data is present and true in missing data
#6)df.isnull().sum() getting sum of every column of true values
#7)abc=df.['state'].astype('float').mean calculating mean for numerical data of column state and returning it in float
#8)df.replace(abc,np.nan,inplace=True) replacing mean in true values
#9) doing it same for every column until column values becomes zero by checking sum (df.isnull().sum)

# %%
import pandas as pd

# %%
df=pd.read_csv("file.csv")

# %%
df
# Out:
#    S.No      Name     State Gender Age
# 0     0     Altaf         ?      M  63
# 1     1     Imran    London      M  33
# 2     2     Hamza    Lahore      M   ?
# 3     3  Bahtawar  Peshawar      F  19
# 4     4   Ranveer     Dehli      M  34
# 5     5      Kaif    Mumbai      ?  32
# 6     6   Deepika    Lahore      F  31
# 7     7    Mahira   Karachi      ?  38
# 8     8    Waseem         ?      M   ?

# %%
import numpy as np

# %%
df.replace("?",np.nan,inplace=True)
df
# Out:
#    S.No      Name     State Gender  Age
# 0     0     Altaf       NaN      M   63
# 1     1     Imran    London      M   33
# 2     2     Hamza    Lahore      M  NaN
# 3     3  Bahtawar  Peshawar      F   19
# 4     4   Ranveer     Dehli      M   34
# 5     5      Kaif    Mumbai    NaN   32
# 6     6   Deepika    Lahore      F   31
# 7     7    Mahira   Karachi    NaN   38
# 8     8    Waseem       NaN      M  NaN

# %%
df.isnull()
# Out:
#     S.No   Name  State  Gender    Age
# 0  False  False   True   False  False
# 1  False  False  False   False  False
# 2  False  False  False   False   True
# 3  False  False  False   False  False
# 4  False  False  False   False  False
# 5  False  False  False    True  False
# 6  False  False  False   False  False
# 7  False  False  False    True  False
# 8  False  False   True   False   True

# %%
df.isnull().sum()
# Out:
# S.No      0
# Name      0
# State     2
# Gender    2
# Age       2
# dtype: int64

# %%
df['State'].head()
# Out:
# 0         NaN
# 1      London
# 2      Lahore
# 3    Peshawar
# 4       Dehli
# Name: State, dtype: object

# %%
m=df['Age'].astype('float').mean()

# %%
m
# Out:
# 35.714285714285715

# %%
df['Age'].replace(np.nan,m,inplace=True)

# %%
df
# Out:
#    S.No      Name     State Gender        Age
# 0     0     Altaf       NaN      M         63
# 1     1     Imran    London      M         33
# 2     2     Hamza    Lahore      M  35.714286
# 3     3  Bahtawar  Peshawar      F         19
# 4     4   Ranveer     Dehli      M         34
# 5     5      Kaif    Mumbai    NaN         32
# 6     6   Deepika    Lahore      F         31
# 7     7    Mahira   Karachi    NaN         38
# 8     8    Waseem       NaN      M  35.714286

# %%
mx=df['Gender'].value_counts().idxmax()

# %%
#ok

# %%
df['Gender'].replace(np.nan,mx,inplace=True)

# %%
df
# Out:
#    S.No      Name     State Gender        Age
# 0     0     Altaf       NaN      M         63
# 1     1     Imran    London      M         33
# 2     2     Hamza    Lahore      M  35.714286
# 3     3  Bahtawar  Peshawar      F         19
# 4     4   Ranveer     Dehli      M         34
# 5     5      Kaif    Mumbai      M         32
# 6     6   Deepika    Lahore      F         31
# 7     7    Mahira   Karachi      M         38
# 8     8    Waseem       NaN      M  35.714286

# %%
mx=df['State'].value_counts().idxmax()

# %%
df['State'].replace(np.nan,mx,inplace=True)

# %%
df
# Out:
#    S.No      Name     State Gender        Age
# 0     0     Altaf    Lahore      M         63
# 1     1     Imran    London      M         33
# 2     2     Hamza    Lahore      M  35.714286
# 3     3  Bahtawar  Peshawar      F         19
# 4     4   Ranveer     Dehli      M         34
# 5     5      Kaif    Mumbai      M         32
# 6     6   Deepika    Lahore      F         31
# 7     7    Mahira   Karachi      M         38
# 8     8    Waseem    Lahore      M  35.714286
