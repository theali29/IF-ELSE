# %%
import os
folderpath = r"C:\Users\DELL\Desktop\wiki"
filepaths = [os.path.join(folderpath,name) for name in os.listdir(folderpath)]
all_files  = []
for path in filepaths:
    with open(path, 'r',encoding="ISO-8859-1") as f:
        file = f.readlines()
        all_files.append(file)

# %%
all_files
# Out:
# [['[[Anarchism]]\n',
#   '\n',
# ...

# %%
sizeOfmyfiles=len(all_files)
print(sizeOfmyfiles)
# Out:
# 1

# %%
listToStr=''.join(map(str,all_files))

# %%
import nltk

# %%
#nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
text=word_tokenize(listToStr)
data=[word for word in text if not word in stopwords.words()]
print(data)
# Out:
# ['[', "'", '[', '[', 'Anarchism', ']', ']', '\\n', "'", ',', "'\\n", "'", ',', "'Anarchism", 'political', 'philosophy', 'advocates', 'stateless', 'societies', 'often', 'defined', 'self-governed', 'voluntary', 'institutions', ',', '``', 'ANARCHISM', ',', 'social', 'philosophy', 'rejects', 'authoritarian', 'government', 'maintains', 'voluntary', 'institutions', 'best', 'suited', 'express', 'man\\', "'s", 'natural', 'social', 'tendencies', '.', "''", 'George', 'Woodcock', '.', '``', 'Anarchism', "''", 'The', 'Encyclopedia', 'Philosophy', '``', 'In', 'society', 'developed', 'lines', ',', 'voluntary', 'associations', 'already', 'begin', 'cover', 'fields', 'human', 'activity', 'would', 'still', 'greater', 'extension', 'substitute', 'state', 'functions', '.', "''", 'Peter', 'Kropotkin', '.', '``', 'Anarchism', "''", 'EncyclopÃ¦dia', 'Britannica', '``', 'Anarchism', '.', "''", 'The', 'Shorter', 'Routledge', 'Encyclopedia', 'Philosophy', '.', '2005.', 'p.', '14', '``', 'Anarchism', 'view', 's
# ...

# %%
data
# Out:
# ['[',
#  "'",
#  '[',
#  '[',
#  'Anarchism',
#  ']',
#  ']',
#  '\\n',
#  "'",
#  ',',
#  "'\\n",
#  "'",
#  ',',
#  "'Anarchism",
#  'political',
#  'philosophy',
#  'advocates',
#  'stateless',
#  'societies',
#  'often',
#  'defined',
#  'self-governed',
#  'voluntary',
#  'institutions',
#  ',',
#  '``',
#  'ANARCHISM',
#  ',',
#  'social',
#  'philosophy',
#  'rejects',
#  'authoritarian',
#  'government',
#  'maintains',
#  'voluntary',
#  'institutions',
#  'best',
#  'suited',
#  'express',
#  'man\\',
#  "'s",
#  'natural',
#  'social',
#  'tendencies',
#  '.',
#  "''",
#  'George',
#  'Woodcock',
#  '.',
#  '``',
#  'Anarchism',
#  "''",
#  'The',
#  'Encyclopedia',
#  'Philosophy',
#  '``',
#  'In',
#  'society',
#  'developed',
#  'lines',
#  ',',
#  'voluntary',
#  'associations',
#  'already',
#  'begin',
#  'cover',
#  'fields',
#  'human',
#  'activity',
#  'would',
#  'still',
#  'greater',
#  'extension',
#  'substitute',
#  'state',
#  'functions',
#  '.',
# ...

# %%
from nltk.stem import WordNetLemmatizer
lemma=WordNetLemmatizer()
lem=[]
for r in data:
    lem.append(lemma.lemmatize(r))
print(lemma.lemmatize('seeks'))
# Out:
# seek

# %%
import re
dataupdate= [ ]
dataupdate=[re.sub('[^a-zA-z0-9]+', '', _)for _ in lem]
dataupdate
# Out:
# ['[',
#  '',
#  '[',
#  '[',
#  'Anarchism',
#  ']',
#  ']',
#  '\\n',
#  '',
#  '',
#  '\\n',
#  '',
#  '',
#  'Anarchism',
#  'political',
#  'philosophy',
#  'advocate',
#  'stateless',
#  'society',
#  'often',
#  'defined',
#  'selfgoverned',
#  'voluntary',
#  'institution',
#  '',
#  '``',
#  'ANARCHISM',
#  '',
#  'social',
#  'philosophy',
#  'reject',
#  'authoritarian',
#  'government',
#  'maintains',
#  'voluntary',
#  'institution',
#  'best',
#  'suited',
#  'express',
#  'man\\',
#  's',
#  'natural',
#  'social',
#  'tendency',
#  '',
#  '',
#  'George',
#  'Woodcock',
#  '',
#  '``',
#  'Anarchism',
#  '',
#  'The',
#  'Encyclopedia',
#  'Philosophy',
#  '``',
#  'In',
#  'society',
#  'developed',
#  'line',
#  '',
#  'voluntary',
#  'association',
#  'already',
#  'begin',
#  'cover',
#  'field',
#  'human',
#  'activity',
#  'would',
#  'still',
#  'greater',
#  'extension',
#  'substitute',
#  'state',
#  'function',
#  '',
#  '',
#  'Peter',
#  'Kropotkin',
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score
#import warnings filter
from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)

vectorizer=TfidfVectorizer(stop_words='english')
X=vectorizer.fit_transform(dataupdate)
true_k=5
model=KMeans(n_clusters=true_k,init='k-means++', max_iter=100,n_init=1)
model.fit(X)
print("Top terms per cluster:")
order_centroids= model.cluster_centers_.argsort()[:,::-1]
terms= vectorizer.get_feature_names()
for i in range(true_k):
    print("Cluster %d:" % i),
    for ind in order_centroids[i,:10]:
        print(' %s' % terms[ind]),
# Out:
# Top terms per cluster:
# Cluster 0:
#  society
#  zhuangzi
#  encouraged
#  elizalde
#  eloquence
#  emerged
#  emerges
#  emir
#  emma
#  emperors
# Cluster 1:
#  anarchism
#  zhuangzi
#  encyclopdia
#  eloquence
#  emerged
#  emerges
#  emir
#  emma
#  emperors
#  encarta
# Cluster 2:
#  x80
#  x93
#  x94
#  x9d
#  x9ccantonalist
#  x98mental
#  x99s
#  1923
#  369
#  743
# Cluster 3:
#  anarchist
#  political
#  proudhon
#  state
#  philosophy
#  authority
#  social
#  press
#  property
#  international
# Cluster 4:
#  2002
#  zhuangzi
#  encyclopdia
#  eloquence
#  emerged
#  emerges
#  emir
#  emma
#  emperors
#  encarta

# %%
print("Guessing :")
Y = vectorizer.transform(["restraint"])
guessing = model.predict(Y)
print(guessing)
 
Y = vectorizer.transform(["claim that this central aspect of anarchism is definitive is to sell anarchise short"])
guessing= model.predict(Y)
print(guessing)
# Out:
# Guessing :
# [3]
# [3]

# %%
vectorizer
# Out:
# TfidfVectorizer(stop_words='english')
