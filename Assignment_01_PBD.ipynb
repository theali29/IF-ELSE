# %% [markdown]
# # Question 1

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
from matplotlib import pyplot
import seaborn as sns
df=pd.read_csv('jsrt_metadata.csv')

# %%
df
# Out:
#          study_id  subtlety  size age  gender       x       y       state  \
# 0    JPCLN001.png       5.0  15.0  53    Male  1634.0   692.0   malignant
# 1    JPCLN002.png       5.0  30.0  78  Female  1614.0  1090.0      benign
# 2    JPCLN003.png       5.0  30.0  63  Female  1303.0   447.0   malignant
# 3    JPCLN004.png       5.0  14.0  68  Female   606.0   836.0      benign
# 4    JPCLN005.png       5.0  35.0  73  Female  1438.0   692.0   malignant
# ..            ...       ...   ...  ..     ...     ...     ...         ...
# 242  JPCNN089.png       NaN   NaN  50    Male     NaN     NaN  non-nodule
# 243  JPCNN090.png       NaN   NaN  68  Female     NaN     NaN  non-nodule
# 244  JPCNN091.png       NaN   NaN  81    Male     NaN     NaN  non-nodule
# 245  JPCNN092.png       NaN   NaN  70  Female     NaN     NaN  non-nodule
# 246  JPCNN093.png       NaN   NaN  41    Male     NaN     NaN  non-nodule
#
#                position           diagnosis
# ...

# %%
mx=df['diagnosis'].value_counts()
mx
# Out:
# lung cancer                                       56
# lung cancer(adenocarcinoma)                       23
# tuberculoma                                       14
# granuloma                                          8
# lung cancer(bronchioloalveolar cell carcinoma)     7
# unknown                                            4
# metastasis of colon cancer                         4
# inflammatory mass                                  4
# pulmonary tuberculosis                             3
# lung abscess                                       2
# Cryptococcosis                                     2
# lung cancer(squamous cell carcinoma)               2
# Inflammatory mass                                  2
# pulmonary hematoma                                 2
# susp. inflammatory mass                            2
# hamartoma                                          2
# sclerosing hemangioma                              2
# lung cancer(large cell carcinoma)                  1
# ...

# %%
plt.pyplot.title("Diagnosis")
plt.pyplot.xlabel("Diseases")
plt.pyplot.ylabel("Frequency")
plt.pyplot.hist(df['diagnosis'].value_counts())
# Out:
# (array([27.,  2.,  1.,  0.,  1.,  0.,  0.,  0.,  0.,  1.]),
#  array([ 1. ,  6.5, 12. , 17.5, 23. , 28.5, 34. , 39.5, 45. , 50.5, 56. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Question 2

# %%
state=df['state'].value_counts()
state
# Out:
# malignant     100
# non-nodule     93
# benign         54
# Name: state, dtype: int64

# %%
lbl=df['state'].unique()
plt.pyplot.pie(df['state'].value_counts(),explode=[0,0.1,0.1],shadow=True,labels=lbl
               ,autopct='%1.1f%%',startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x152d09e8730>,
# ...
#  [Text(-1.051228217420429, 0.32391238769004665, 'malignant'),
#   Text(0.6627131763988918, -1.0004055406820234, 'benign'),
#   Text(0.7609032053706036, 0.9279150349340941, 'non-nodule')],
#  [Text(-0.5733972095020522, 0.17667948419457088, '40.5%'),
#   Text(0.3865826862326868, -0.5835698987311803, '37.7%'),
#   Text(0.4438602031328521, 0.5412837703782216, '21.9%')])

# %% [markdown]
# # Question 3

# %%
df['gender'].value_counts()
# Out:
# Female    128
# Male      119
# Name: gender, dtype: int64

# %%
lbl2=df['gender'].unique()

plt.pyplot.pie(df['gender'].value_counts(),explode=[0,0.1],shadow=True,labels=lbl2
               ,autopct='%1.1f%%',startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x152d25cc6d0>,
# ...
#  [Text(-1.098198743276378, -0.06292471903937331, 'Male'),
#   Text(1.1980349926651397, 0.06864514804295202, 'Female')],
#  [Text(-0.5990174963325697, -0.03432257402147635, '51.8%'),
#   Text(0.6988537457213314, 0.04004300302505534, '48.2%')])

# %%
count1=df[['gender','diagnosis']].value_counts()
lbl3=df[['gender','diagnosis']].value_counts().index.tolist()
count1
# Out:
# gender  diagnosis
# Female  lung cancer                                       32
# Male    lung cancer                                       24
# Female  lung cancer(adenocarcinoma)                       15
# Male    tuberculoma                                        9
#         lung cancer(adenocarcinoma)                        8
#         granuloma                                          6
# Female  tuberculoma                                        5
#         lung cancer(bronchioloalveolar cell carcinoma)     4
#         unknown                                            4
# Male    pulmonary tuberculosis                             3
# Female  metastasis of colon cancer                         3
# Male    lung cancer(bronchioloalveolar cell carcinoma)     3
# Female  inflammatory mass                                  2
#         Inflammatory mass                                  2
# Male    lung cancer(squamous cell carcinoma)               2
# ...

# %%
plt.pyplot.pie(count1,labels=lbl3,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x152d369c340>,
# ...
#  [Text(0.8738257943595382, 0.668153037194266, "('Female', 'lung cancer')"),
#   Text(-0.2447730130080498, 1.0724207066739067, "('Male', 'lung cancer')"),
#   Text(-0.9373174319015161, 0.5757048131234851, "('Female', 'lung cancer(adenocarcinoma)')"),
#   Text(-1.0979406574654567, 0.06727787663356226, "('Male', 'tuberculoma')"),
#   Text(-1.0554422864728479, -0.30990575974797063, "('Male', 'lung cancer(adenocarcinoma)')"),
#   Text(-0.925378917750827, -0.5947048499737565, "('Male', 'granuloma')"),
#   Text(-0.7698434589290138, -0.7857105375036102, "('Female', 'tuberculoma')"),
#   Text(-0.6134575826042715, -0.9130551978633732, "('Female', 'lung cancer(bronchioloalveolar cell carcinoma)')"),
#   Text(-0.4569565680630455, -1.0005951703381561, "('Female', 'unknown')"),
#   Text(-0.3099058709178124, -1.0554422538304369, "('Male', 'pulmonary tuberculosis')"),
# ...

# %%
count1.plot(kind='pie', figsize=(50,10))
# Out:
# <AxesSubplot:ylabel='None'>
